# %%
import pandas as pd
import numpy as np

# %%
pop = pd.read_csv("population.csv")
pop.head(10)
# Out:
#    Year  District.Code District.Name  Neighborhood.Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
# 5  2017              2      Eixample                  6
# 6  2017              2      Eixample                  7
# 7  2017              2      Eixample                  8
# 8  2017              2      Eixample                  9
# 9  2017              2      Eixample                 10
#
#                        Neighborhood.Name Gender  Age  Number
# 0                               el Raval   Male  0-4     224
# 1                         el Barri Gòtic   Male  0-4      50
# 2                         la Barceloneta   Male  0-4      43
# 3  Sant Pere, Santa Caterina i la Ribera   Male  0-4      95
# 4                          el Fort Pienc   Male  0-4     124
# 5                     la Sagrada Família   Male  0-4     191
# 6                 la Dreta de l'Eixample   Male  0-4     176
# 7        l'Antiga Esquerra de l'Eixample   Male  0-4     158
# 8         la Nova Esquerra de l'Eixample   Male  0-4     220
# 9                            Sant Antoni   Male  0-4     143

# %%
pop.dtypes
# Out:
# Year                  int64
# District.Code         int64
# District.Name        object
# Neighborhood.Code     int64
# Neighborhood.Name    object
# Gender               object
# Age                  object
# Number                int64
# dtype: object

# %%
null_cols = pop.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Series([], dtype: int64)

# %%
for year in set(pop["Year"]):
   print(pop[pop["Year"] == year].head(10))
# Out:
#        Year  District.Code District.Name  Neighborhood.Code  \
# 14016  2016              1  Ciutat Vella                  1
# 14017  2016              1  Ciutat Vella                  2
# 14018  2016              1  Ciutat Vella                  3
# 14019  2016              1  Ciutat Vella                  4
# 14020  2016              2      Eixample                  5
# 14021  2016              2      Eixample                  6
# 14022  2016              2      Eixample                  7
# 14023  2016              2      Eixample                  8
# 14024  2016              2      Eixample                  9
# 14025  2016              2      Eixample                 10
#
#                            Neighborhood.Name Gender  Age  Number
# 14016                               el Raval   Male  0-4     209
# 14017                         el Barri Gòtic   Male  0-4      45
# 14018                         la Barceloneta   Male  0-4      56
# 14019  Sant Pere, Santa Caterina i la Ribera   Male  0-4      84
# 14020                          el Fort Pienc   Male  0-4     143
# 14021                     la Sagrada Família   Male  0-4     198
# 14022                 la Dreta de l'Eixample   Male  0-4     209
# 14023        l'Antiga Esquerra de l'Eixample   Male  0-4     173
# 14024         la Nova Esquerra de l'Eixample   Male  0-4     227
# 14025                            Sant Antoni   Male  0-4     164
#    Year  District.Code District.Name  Neighborhood.Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
# 5  2017              2      Eixample                  6
# 6  2017              2      Eixample                  7
# 7  2017              2      Eixample                  8
# 8  2017              2      Eixample                  9
# 9  2017              2      Eixample                 10
#
#                        Neighborhood.Name Gender  Age  Number
# 0                               el Raval   Male  0-4     224
# 1                         el Barri Gòtic   Male  0-4      50
# 2                         la Barceloneta   Male  0-4      43
# 3  Sant Pere, Santa Caterina i la Ribera   Male  0-4      95
# 4                          el Fort Pienc   Male  0-4     124
# 5                     la Sagrada Família   Male  0-4     191
# 6                 la Dreta de l'Eixample   Male  0-4     176
# 7        l'Antiga Esquerra de l'Eixample   Male  0-4     158
# 8         la Nova Esquerra de l'Eixample   Male  0-4     220
# 9                            Sant Antoni   Male  0-4     143
#        Year  District.Code District.Name  Neighborhood.Code  \
# 56064  2013              1  Ciutat Vella                  1
# 56065  2013              1  Ciutat Vella                  2
# 56066  2013              1  Ciutat Vella                  3
# 56067  2013              1  Ciutat Vella                  4
# 56068  2013              2      Eixample                  5
# 56069  2013              2      Eixample                  6
# 56070  2013              2      Eixample                  7
# 56071  2013              2      Eixample                  8
# 56072  2013              2      Eixample                  9
# 56073  2013              2      Eixample                 10
#
#                            Neighborhood.Name Gender  Age  Number
# 56064                               el Raval   Male  0-4     227
# 56065                         el Barri Gòtic   Male  0-4      49
# 56066                         la Barceloneta   Male  0-4      50
# 56067  Sant Pere, Santa Caterina i la Ribera   Male  0-4      78
# 56068                          el Fort Pienc   Male  0-4     120
# 56069                     la Sagrada Família   Male  0-4     221
# 56070                 la Dreta de l'Eixample   Male  0-4     165
# 56071        l'Antiga Esquerra de l'Eixample   Male  0-4     125
# 56072         la Nova Esquerra de l'Eixample   Male  0-4     200
# 56073                            Sant Antoni   Male  0-4     149
#        Year  District.Code District.Name  Neighborhood.Code  \
# 42048  2014              1  Ciutat Vella                  1
# 42049  2014              1  Ciutat Vella                  2
# 42050  2014              1  Ciutat Vella                  3
# 42051  2014              1  Ciutat Vella                  4
# 42052  2014              2      Eixample                  5
# 42053  2014              2      Eixample                  6
# 42054  2014              2      Eixample                  7
# 42055  2014              2      Eixample                  8
# 42056  2014              2      Eixample                  9
# 42057  2014              2      Eixample                 10
#
#                            Neighborhood.Name Gender  Age  Number
# 42048                               el Raval   Male  0-4     210
# 42049                         el Barri Gòtic   Male  0-4      51
# 42050                         la Barceloneta   Male  0-4      55
# 42051  Sant Pere, Santa Caterina i la Ribera   Male  0-4      86
# 42052                          el Fort Pienc   Male  0-4     120
# 42053                     la Sagrada Família   Male  0-4     162
# 42054                 la Dreta de l'Eixample   Male  0-4     199
# 42055        l'Antiga Esquerra de l'Eixample   Male  0-4     174
# 42056         la Nova Esquerra de l'Eixample   Male  0-4     200
# 42057                            Sant Antoni   Male  0-4     154
#        Year  District.Code District.Name  Neighborhood.Code  \
# 28032  2015              1  Ciutat Vella                  1
# 28033  2015              1  Ciutat Vella                  2
# 28034  2015              1  Ciutat Vella                  3
# 28035  2015              1  Ciutat Vella                  4
# 28036  2015              2      Eixample                  5
# 28037  2015              2      Eixample                  6
# 28038  2015              2      Eixample                  7
# 28039  2015              2      Eixample                  8
# 28040  2015              2      Eixample                  9
# 28041  2015              2      Eixample                 10
#
#                            Neighborhood.Name Gender  Age  Number
# 28032                               el Raval   Male  0-4     227
# 28033                         el Barri Gòtic   Male  0-4      34
# 28034                         la Barceloneta   Male  0-4      40
# 28035  Sant Pere, Santa Caterina i la Ribera   Male  0-4      92
# 28036                          el Fort Pienc   Male  0-4     127
# 28037                     la Sagrada Família   Male  0-4     217
# 28038                 la Dreta de l'Eixample   Male  0-4     191
# 28039        l'Antiga Esquerra de l'Eixample   Male  0-4     160
# 28040         la Nova Esquerra de l'Eixample   Male  0-4     221
# 28041                            Sant Antoni   Male  0-4     149

# %%
pop.columns
# Out:
# Index(['Year', 'District.Code', 'District.Name', 'Neighborhood.Code',
#        'Neighborhood.Name', 'Gender', 'Age', 'Number'],
#       dtype='object')

# %%
test = pd.read_csv("./life_expectancy/Life_expectancy_of_the-city_of_Barcelona.csv")

# %%
single2018 = pd.read_csv("./population_by_neighborhood_and_genre/Population_living_alone/2018_padro_viu_sola_edat_quinquennal.csv")
single2018.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2018               1  Ciutat Vella           1
# 1  2018               1  Ciutat Vella           2
# 2  2018               1  Ciutat Vella           3
# 3  2018               1  Ciutat Vella           4
# 4  2018               2      Eixample           5
#
#                                Nom_Barri  Sexe Edat quinquennal  Nombre
# 0                               el Raval  Home        < 25 anys      98
# 1                         el Barri Gòtic  Home        < 25 anys      53
# 2                         la Barceloneta  Home        < 25 anys      37
# 3  Sant Pere, Santa Caterina i la Ribera  Home        < 25 anys      73
# 4                          el Fort Pienc  Home        < 25 anys      25

# %%
single2018.columns
# Out:
# Index(['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri',
#        'Sexe', 'Edat quinquennal', 'Nombre'],
#       dtype='object')

# %%
single2018.dtypes
single2018.columns = ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri',
       'Sexe', 'Age_by_5', 'Number']
single2018.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2018               1  Ciutat Vella           1
# 1  2018               1  Ciutat Vella           2
# 2  2018               1  Ciutat Vella           3
# 3  2018               1  Ciutat Vella           4
# 4  2018               2      Eixample           5
#
#                                Nom_Barri  Sexe   Age_by_5  Number
# 0                               el Raval  Home  < 25 anys      98
# 1                         el Barri Gòtic  Home  < 25 anys      53
# 2                         la Barceloneta  Home  < 25 anys      37
# 3  Sant Pere, Santa Caterina i la Ribera  Home  < 25 anys      73
# 4                          el Fort Pienc  Home  < 25 anys      25

# %%
single_by_district2018 = single2018[["Nom_Districte", "Sexe", "Age_by_5", "Number"]]
single_by_neighborhood2018 = single2018[["Nom_Barri", "Sexe", "Age_by_5", "Number"]]
single_by_district2018.head()
# Out:
#   Nom_Districte  Sexe   Age_by_5  Number
# 0  Ciutat Vella  Home  < 25 anys      98
# 1  Ciutat Vella  Home  < 25 anys      53
# 2  Ciutat Vella  Home  < 25 anys      37
# 3  Ciutat Vella  Home  < 25 anys      73
# 4      Eixample  Home  < 25 anys      25

# %%
single_by_district2018.groupby(['Nom_Districte', 'Age_by_5', "Sexe"]).sum().sort_values(["Number"], ascending = False).head(10)
# Out:
#                                 Number
# Nom_Districte  Age_by_5   Sexe
# Eixample       80-84 anys Dona    2408
#                85-89 anys Dona    2315
#                70-74 anys Dona    2140
#                75-79 anys Dona    1975
# Sant Martí     80-84 anys Dona    1950
# Eixample       65-69 anys Dona    1943
# Nou Barris     80-84 anys Dona    1760
# Horta-Guinardó 80-84 anys Dona    1756
# Sant Martí     85-89 anys Dona    1680
# Eixample       60-64 anys Dona    1657

# %%
single_by_neighborhood2018.groupby(['Nom_Barri', 'Age_by_5', "Sexe"]).sum().sort_values(["Number"], ascending = False).head(10)
# Out:
#                                                 Number
# Nom_Barri                      Age_by_5   Sexe
# la Vila de Gràcia              30-34 anys Dona     581
#                                35-39 anys Dona     527
# la Nova Esquerra de l'Eixample 80-84 anys Dona     521
# la Sagrada Família             85-89 anys Dona     504
#                                80-84 anys Dona     499
# la Nova Esquerra de l'Eixample 70-74 anys Dona     495
# Sant Andreu                    80-84 anys Dona     489
# la Nova Esquerra de l'Eixample 65-69 anys Dona     478
#                                85-89 anys Dona     476
# la Vila de Gràcia              35-39 anys Home     462

# %%
single_by_district2018.groupby(['Nom_Districte', 'Sexe']).sum().sort_values(["Number", "Nom_Districte"], ascending = [True, False]).head(10)
# Out:
#                           Number
# Nom_Districte       Sexe
# Les Corts           Home    3428
# Sarrià-Sant Gervasi Home    6025
# Sant Andreu         Home    6221
# Les Corts           Dona    6282
# Gràcia              Home    6629
# Nou Barris          Home    7010
# Ciutat Vella        Home    7708
# Horta-Guinardó      Home    7756
# Ciutat Vella        Dona    8186
# Sants-Montjuïc      Home    9031

# %%
single_by_neighborhood2018.groupby(['Nom_Barri', 'Sexe']).sum().sort_values(["Number",'Nom_Barri'], ascending = [False, True]).head(10)
# Out:
#                                       Number
# Nom_Barri                       Sexe
# la Vila de Gràcia               Dona    5531
# la Nova Esquerra de l'Eixample  Dona    5114
# la Sagrada Família              Dona    4705
# Sant Andreu                     Dona    4057
# l'Antiga Esquerra de l'Eixample Dona    4022
# Sant Gervasi - Galvany          Dona    3925
# la Dreta de l'Eixample          Dona    3882
# les Corts                       Dona    3816
# Sants                           Dona    3601
# Sant Antoni                     Dona    3468

# %%
single_by_district2018.groupby('Sexe').sum().sort_values('Number', ascending = [False])
# Out:
#       Number
# Sexe
# Dona  126905
# Home   78810

# %%
single_by_district2018.groupby(['Age_by_5', "Sexe"]).sum().sort_values(["Number"], ascending = False).head()
# Out:
#                  Number
# Age_by_5   Sexe
# 80-84 anys Dona   14284
# 85-89 anys Dona   12761
# 70-74 anys Dona   11982
# 75-79 anys Dona   11066
# 65-69 anys Dona   10350

# %%
sum2018 = single_by_district2018.groupby(['Nom_Districte','Age_by_5']).agg({'Number':'sum'}).sort_values(["Number"], ascending = False)
sum2018.head(5)
# Out:
#                           Number
# Nom_Districte Age_by_5
# Eixample      30-34 anys    3101
#               35-39 anys    3080
#               70-74 anys    3012
#               80-84 anys    2971
#               65-69 anys    2884

# %%
single_by_neighborhood2018.groupby(['Nom_Barri','Age_by_5']).agg({'Number':'sum'}).sort_values(["Number"], ascending = False).head(10)
# Out:
#                                            Number
# Nom_Barri                      Age_by_5
# la Vila de Gràcia              30-34 anys    1004
#                                35-39 anys     989
#                                40-44 anys     837
# el Raval                       35-39 anys     698
# la Nova Esquerra de l'Eixample 70-74 anys     694
# el Raval                       30-34 anys     687
# la Nova Esquerra de l'Eixample 65-69 anys     684
# la Vila de Gràcia              25-29 anys     656
# la Nova Esquerra de l'Eixample 30-34 anys     640
#                                80-84 anys     635

# %%
sum2018_total = single_by_district2018.groupby("Nom_Districte").agg({'Number':'sum'}).sort_values(["Number"], ascending = False)
sum2018_total
# Out:
#                      Number
# Nom_Districte
# Eixample              38094
# Sant Martí            27038
# Sants-Montjuïc        23189
# Horta-Guinardó        20671
# Nou Barris            19102
# Gràcia                18476
# Sarrià-Sant Gervasi   17026
# Sant Andreu           16515
# Ciutat Vella          15894
# Les Corts              9710

# %%
single_by_neighborhood2018.groupby("Nom_Barri").agg({'Number':'sum'}).sort_values(["Number"], ascending = False).head()
# Out:
#                                  Number
# Nom_Barri
# la Vila de Gràcia                  8801
# la Nova Esquerra de l'Eixample     8146
# la Sagrada Família                 7229
# Sant Andreu                        6533
# l'Antiga Esquerra de l'Eixample    6509

# %%
sum2018_total["Number"].describe()
# Out:
# count       10.000000
# mean     20571.500000
# std       7682.175159
# min       9710.000000
# 25%      16642.750000
# 50%      18789.000000
# 75%      22559.500000
# max      38094.000000
# Name: Number, dtype: float64

# %%
sum2018["Number"].describe()
# Out:
# count     170.000000
# mean     1210.088235
# std       732.967841
# min        11.000000
# 25%       670.500000
# 50%      1201.000000
# 75%      1652.500000
# max      3101.000000
# Name: Number, dtype: float64

# %%
single2008 = pd.read_csv("./population_by_neighborhood_and_genre/Population_living_alone/2008_padro_viu_sola_edat_quinquennal.csv")
single2008.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2008               1  Ciutat Vella           1
# 1  2008               1  Ciutat Vella           2
# 2  2008               1  Ciutat Vella           3
# 3  2008               1  Ciutat Vella           4
# 4  2008               2      Eixample           5
#
#                                Nom_Barri  Sexe Edat quinquennal  Nombre
# 0                               el Raval  Home        < 24 anys      86
# 1                         el Barri Gòtic  Home        < 24 anys      39
# 2                         la Barceloneta  Home        < 24 anys      34
# 3  Sant Pere, Santa Caterina i la Ribera  Home        < 24 anys      32
# 4                          el Fort Pienc  Home        < 24 anys      49

# %%
single2008.columns = ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri',
       'Sexe', 'Age_by_5', 'Number']
single2008.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2008               1  Ciutat Vella           1
# 1  2008               1  Ciutat Vella           2
# 2  2008               1  Ciutat Vella           3
# 3  2008               1  Ciutat Vella           4
# 4  2008               2      Eixample           5
#
#                                Nom_Barri  Sexe   Age_by_5  Number
# 0                               el Raval  Home  < 24 anys      86
# 1                         el Barri Gòtic  Home  < 24 anys      39
# 2                         la Barceloneta  Home  < 24 anys      34
# 3  Sant Pere, Santa Caterina i la Ribera  Home  < 24 anys      32
# 4                          el Fort Pienc  Home  < 24 anys      49

# %%
single2008n = single2008[single2008.Nom_Barri != 'No consta']

# %%
single_by_district2008 = single2008n[["Nom_Districte", "Sexe", "Age_by_5", "Number"]]
single_by_neighborhood2008 = single2008n[["Nom_Barri", "Sexe", "Age_by_5", "Number"]]
single_by_district2008.head()
# Out:
#   Nom_Districte  Sexe   Age_by_5  Number
# 0  Ciutat Vella  Home  < 24 anys      86
# 1  Ciutat Vella  Home  < 24 anys      39
# 2  Ciutat Vella  Home  < 24 anys      34
# 3  Ciutat Vella  Home  < 24 anys      32
# 4      Eixample  Home  < 24 anys      49

# %%
single_by_district2008.groupby(['Nom_Districte','Age_by_5', 'Sexe']).agg({'Number':'sum'}).head(10)
# Out:
#                                Number
# Nom_Districte Age_by_5   Sexe
# Ciutat Vella  25-29 anys Dona     645
#                          Home     630
#               30-34 anys Dona     864
#                          Home    1049
#               35-39 anys Dona     647
#                          Home    1052
#               40-44 anys Dona     491
#                          Home     763
#               45-49 anys Dona     377
#                          Home     641

# %%
single_by_district2008.groupby(['Nom_Districte','Age_by_5']).sum().sort_values(["Number"], ascending = False).head(10)
# Out:
#                           Number
# Nom_Districte Age_by_5
# Eixample      80-84 anys    3620
#               30-34 anys    3619
#               75-79 anys    3523
#               35-39 anys    3078
#               70-74 anys    2742
# Sant Martí    75-79 anys    2604
# Eixample      60-64 anys    2556
#               25-29 anys    2522
#               40-44 anys    2511
#               85-89 anys    2489

# %%
single_by_neighborhood2008.groupby(['Nom_Barri', 'Age_by_5', "Sexe"]).sum().sort_values(["Number"], ascending = False).head(10)
# Out:
#                                                  Number
# Nom_Barri                       Age_by_5   Sexe
# la Vila de Gràcia               80-84 anys Dona     659
# la Sagrada Família              80-84 anys Dona     638
# la Nova Esquerra de l'Eixample  80-84 anys Dona     632
# la Vila de Gràcia               30-34 anys Dona     630
# la Sagrada Família              75-79 anys Dona     605
# la Vila de Gràcia               75-79 anys Dona     605
# la Nova Esquerra de l'Eixample  75-79 anys Dona     604
# l'Antiga Esquerra de l'Eixample 80-84 anys Dona     559
# la Vila de Gràcia               30-34 anys Home     542
# Sant Antoni                     80-84 anys Dona     506

# %%
total2008 = single_by_neighborhood2008.groupby(['Nom_Barri', 'Sexe']).sum().sort_values(["Number",'Nom_Barri'], ascending = [False, True]).head(10)
total2008.head()
# Out:
#                                       Number
# Nom_Barri                       Sexe
# la Vila de Gràcia               Dona    5649
# la Nova Esquerra de l'Eixample  Dona    5087
# la Sagrada Família              Dona    4797
# l'Antiga Esquerra de l'Eixample Dona    4245
# la Dreta de l'Eixample          Dona    4028

# %%
single_by_neighborhood2008.groupby(['Nom_Barri','Age_by_5']).agg({'Number':'sum'}).sort_values(["Number"], ascending = False).head(10)
# Out:
#                                            Number
# Nom_Barri                      Age_by_5
# la Vila de Gràcia              30-34 anys    1172
#                                35-39 anys     876
# la Nova Esquerra de l'Eixample 30-34 anys     791
# la Vila de Gràcia              80-84 anys     785
#                                25-29 anys     756
# el Raval                       30-34 anys     748
# la Nova Esquerra de l'Eixample 80-84 anys     743
# la Sagrada Família             80-84 anys     741
# la Nova Esquerra de l'Eixample 75-79 anys     732
# la Vila de Gràcia              75-79 anys     723

# %%
total2008["Number"].describe()
# Out:
# count      10.000000
# mean     4193.700000
# std       742.881036
# min      3487.000000
# 25%      3645.500000
# 50%      3900.000000
# 75%      4659.000000
# max      5649.000000
# Name: Number, dtype: float64

# %%
sum2008_total = single_by_district2008.groupby("Nom_Districte").agg({'Number':'sum'}).sort_values(["Number"], ascending = False)
sum2008_total
# Out:
#                      Number
# Nom_Districte
# Eixample              37551
# Sant Martí            24218
# Sants-Montjuïc        22102
# Horta-Guinardó        18881
# Gràcia                18208
# Nou Barris            17243
# Sarrià-Sant Gervasi   16201
# Ciutat Vella          15750
# Sant Andreu           14971
# Les Corts              8990

# %%
sum2008_total["Number"].describe()
# Out:
# count       10.000000
# mean     19411.500000
# std       7585.472391
# min       8990.000000
# 25%      15862.750000
# 50%      17725.500000
# 75%      21296.750000
# max      37551.000000
# Name: Number, dtype: float64

# %%
sum2018_total["Number"].describe()
# Out:
# count       10.000000
# mean     20571.500000
# std       7682.175159
# min       9710.000000
# 25%      16642.750000
# 50%      18789.000000
# 75%      22559.500000
# max      38094.000000
# Name: Number, dtype: float64

# %%
change = (sum2018_total["Number"].mean() - sum2008_total["Number"].mean())/sum2018_total["Number"].mean()*100

# %%
change
# Out:
# 5.6388693094815645
