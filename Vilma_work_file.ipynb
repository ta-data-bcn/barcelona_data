# %%
import pandas as pd
import numpy as np

# %%
pop = pd.read_csv("population.csv")
pop.head(10)
# Out:
#    Year  District.Code District.Name  Neighborhood.Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
# 5  2017              2      Eixample                  6
# 6  2017              2      Eixample                  7
# 7  2017              2      Eixample                  8
# 8  2017              2      Eixample                  9
# 9  2017              2      Eixample                 10
#
#                        Neighborhood.Name Gender  Age  Number
# 0                               el Raval   Male  0-4     224
# 1                         el Barri Gòtic   Male  0-4      50
# 2                         la Barceloneta   Male  0-4      43
# 3  Sant Pere, Santa Caterina i la Ribera   Male  0-4      95
# ...

# %%
pop.dtypes
# Out:
# Year                  int64
# District.Code         int64
# District.Name        object
# Neighborhood.Code     int64
# Neighborhood.Name    object
# Gender               object
# Age                  object
# Number                int64
# dtype: object

# %%
null_cols = pop.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Series([], dtype: int64)

# %%
for year in set(pop["Year"]):
   print(pop[pop["Year"] == year].head(10))
# Out:
#        Year  District.Code District.Name  Neighborhood.Code  \
# 14016  2016              1  Ciutat Vella                  1
# 14017  2016              1  Ciutat Vella                  2
# 14018  2016              1  Ciutat Vella                  3
# 14019  2016              1  Ciutat Vella                  4
# 14020  2016              2      Eixample                  5
# 14021  2016              2      Eixample                  6
# 14022  2016              2      Eixample                  7
# 14023  2016              2      Eixample                  8
# 14024  2016              2      Eixample                  9
# 14025  2016              2      Eixample                 10
#
#                            Neighborhood.Name Gender  Age  Number
# 14016                               el Raval   Male  0-4     209
# 14017                         el Barri Gòtic   Male  0-4      45
# 14018                         la Barceloneta   Male  0-4      56
# ...

# %%
pop.columns
# Out:
# Index(['Year', 'District.Code', 'District.Name', 'Neighborhood.Code',
#        'Neighborhood.Name', 'Gender', 'Age', 'Number'],
#       dtype='object')

# %%
alone = pd.read_csv("dfTOTAL.csv")

# %%
alone.head()
# Out:
#    Unnamed: 0  Order        Name  Gender       Decade  Frequency
# 0           0      1       MARIA  Female  Before 1930       2085
# 1           1      2      CARMEN  Female  Before 1930       1463
# 2           2      3      JOSEFA  Female  Before 1930       1032
# 3           3      4  MONTSERRAT  Female  Before 1930        879
# 4           4      5        ROSA  Female  Before 1930        762

# %%
test = pd.read_csv("./life_expectancy/Life_expectancy_of_the-city_of_Barcelona.csv")

# %%
test
# Out:
#          Dte.                                            Barris  2006-2010  \
# 0   BARCELONA                                               NaN       82.5
# 1           1                                       1. el Raval       82.6
# 2           1                                 2. el Barri Gòtic       84.7
# 3           1                                 3. la Barceloneta       83.3
# 4           1          4. Sant Pere, Santa Caterina i la Ribera       85.1
# 5           2                                  5. el Fort Pienc       86.7
# 6           2                             6. la Sagrada Família       86.5
# 7           2                         7. la Dreta de l'Eixample       84.5
# 8           2                8. l'Antiga Esquerra de l'Eixample       86.1
# 9           2                 9. la Nova Esquerra de l'Eixample       86.4
# 10          2                                   10. Sant Antoni       85.8
# ...

# %%
single = pd.read_csv("./population_by_neighborhood_and_genre/Population_living_alone/2018_padro_viu_sola_edat_quinquennal.csv")
single.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2018               1  Ciutat Vella           1
# 1  2018               1  Ciutat Vella           2
# 2  2018               1  Ciutat Vella           3
# 3  2018               1  Ciutat Vella           4
# 4  2018               2      Eixample           5
#
#                                Nom_Barri  Sexe Edat quinquennal  Nombre
# 0                               el Raval  Home        < 25 anys      98
# 1                         el Barri Gòtic  Home        < 25 anys      53
# 2                         la Barceloneta  Home        < 25 anys      37
# 3  Sant Pere, Santa Caterina i la Ribera  Home        < 25 anys      73
# 4                          el Fort Pienc  Home        < 25 anys      25

# %%
single.columns
# Out:
# Index(['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri',
#        'Sexe', 'Edat quinquennal', 'Nombre'],
#       dtype='object')

# %%
single.dtypes
single.columns = ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri',
       'Sexe', 'Age_by_5', 'Number']
single.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2018               1  Ciutat Vella           1
# 1  2018               1  Ciutat Vella           2
# 2  2018               1  Ciutat Vella           3
# 3  2018               1  Ciutat Vella           4
# 4  2018               2      Eixample           5
#
#                                Nom_Barri  Sexe   Age_by_5  Number
# 0                               el Raval  Home  < 25 anys      98
# 1                         el Barri Gòtic  Home  < 25 anys      53
# 2                         la Barceloneta  Home  < 25 anys      37
# 3  Sant Pere, Santa Caterina i la Ribera  Home  < 25 anys      73
# 4                          el Fort Pienc  Home  < 25 anys      25

# %%
single_by_district = single[["Any", "Codi_Districte", "Nom_Districte", "Sexe", "Age_by_5", "Number"]]
single_by_district.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Sexe   Age_by_5  Number
# 0  2018               1  Ciutat Vella  Home  < 25 anys      98
# 1  2018               1  Ciutat Vella  Home  < 25 anys      53
# 2  2018               1  Ciutat Vella  Home  < 25 anys      37
# 3  2018               1  Ciutat Vella  Home  < 25 anys      73
# 4  2018               2      Eixample  Home  < 25 anys      25

# %%
single_by_district[single_by_district['Any']==2018].groupby(['Nom_Districte','Age_by_5']).sum()
# Out:
#                                       Any  Codi_Districte  Number
# Nom_Districte       Age_by_5
# Ciutat Vella        100 anys i més  16144               8      11
#                     25-29 anys      16144               8    1616
#                     30-34 anys      16144               8    1866
#                     35-39 anys      16144               8    1822
#                     40-44 anys      16144               8    1488
#                     45-49 anys      16144               8    1209
#                     50-54 anys      16144               8    1022
#                     55-59 anys      16144               8     914
#                     60-64 anys      16144               8     941
#                     65-69 anys      16144               8     863
#                     70-74 anys      16144               8     864
#                     75-79 anys      16144               8     668
#                     80-84 anys      16144               8     841
# ...
